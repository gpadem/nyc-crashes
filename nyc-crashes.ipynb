# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/gulce/ANT-Theano-2-27/additional_resources/datasets/NYC Motor Vehicle Crashes/data_100000.csv')

# %%
df.head()
# Out:
#                 crash_date crash_time        borough  zip_code   latitude  \
# 0  2017-04-18T00:00:00.000      23:10  STATEN ISLAND   10312.0  40.536728
# 1  2017-05-06T00:00:00.000      13:00          BRONX   10472.0  40.829052
# 2  2017-04-27T00:00:00.000      17:15         QUEENS   11420.0  40.677303
# 3  2017-05-09T00:00:00.000      20:10            NaN       NaN  40.624958
# 4  2017-04-18T00:00:00.000      14:00          BRONX   10456.0  40.828846
#
#    longitude                 location                    on_street_name  \
# 0 -74.193344  (40.536728, -74.193344)                               NaN
# 1 -73.850380   (40.829052, -73.85038)  CASTLE HILL AVENUE
# 2 -73.804565  (40.677303, -73.804565)  135 STREET
# 3 -74.145775  (40.624958, -74.145775)  FOREST AVENUE
# 4 -73.903120   (40.828846, -73.90312)                               NaN
#
#     off_street_name                         cross_street_name  ...  \
# 0               NaN  243       DARLINGTON AVENUE               ...
# ...

# %%
df.shape
# Out:
# (100000, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     100000 non-null  object
#  1   crash_time                     100000 non-null  object
#  2   borough                        64974 non-null   object
#  3   zip_code                       64966 non-null   float64
#  4   latitude                       91965 non-null   float64
#  5   longitude                      91965 non-null   float64
#  6   location                       91965 non-null   object
#  7   on_street_name                 73991 non-null   object
#  8   off_street_name                47125 non-null   object
#  9   cross_street_name              25967 non-null   object
#  10  number_of_persons_injured      100000 non-null  int64
#  11  number_of_persons_killed       100000 non-null  int64
# ...

# %%
a = df.iloc[:, 13:14]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.shape
# Out:
# (100000, 1)

# %%
a.count()
# Out:
# number_of_pedestrians_killed    100000
# dtype: int64

# %%
a.mean()
# Out:
# number_of_pedestrians_killed    0.00064
# dtype: float64

# %%
df.isnull().sum()
# Out:
# crash_date                           0
# crash_time                           0
# borough                          35026
# zip_code                         35034
# latitude                          8035
# longitude                         8035
# location                          8035
# on_street_name                   26009
# off_street_name                  52875
# cross_street_name                74033
# number_of_persons_injured            0
# number_of_persons_killed             0
# number_of_pedestrians_injured        0
# number_of_pedestrians_killed         0
# number_of_cyclist_injured            0
# number_of_cyclist_killed             0
# number_of_motorist_injured           0
# number_of_motorist_killed            0
# contributing_factor_vehicle_1      371
# contributing_factor_vehicle_2    19243
# contributing_factor_vehicle_3    91239
# contributing_factor_vehicle_4    97760
# contributing_factor_vehicle_5    99333
# collision_id                         0
# ...

# %%
trial_df = df.iloc[:, 2:18]

# %%
trial_df.head()
# Out:
#          borough  zip_code   latitude  longitude                 location  \
# 0  STATEN ISLAND   10312.0  40.536728 -74.193344  (40.536728, -74.193344)
# 1          BRONX   10472.0  40.829052 -73.850380   (40.829052, -73.85038)
# 2         QUEENS   11420.0  40.677303 -73.804565  (40.677303, -73.804565)
# 3            NaN       NaN  40.624958 -74.145775  (40.624958, -74.145775)
# 4          BRONX   10456.0  40.828846 -73.903120   (40.828846, -73.90312)
#
#                      on_street_name   off_street_name  \
# 0                               NaN               NaN
# 1  CASTLE HILL AVENUE                BLACKROCK AVENUE
# 2  135 STREET                          FOCH BOULEVARD
# 3  FOREST AVENUE                      RICHMOND AVENUE
# 4                               NaN               NaN
#
#                           cross_street_name  number_of_persons_injured  \
# 0  243       DARLINGTON AVENUE                                       0
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
trial_df.duplicated().any()
# Out:
# True

# %%
trial_df_duplicate = trial_df[trial_df.duplicated()]

# %%
type(trial_df_duplicate)
# Out:
# pandas.core.frame.DataFrame

# %%
trial_df_duplicate
# Out:
#              borough  zip_code   latitude  longitude                 location  \
# 114           QUEENS   11419.0  40.686234 -73.824180   (40.686234, -73.82418)
# 238              NaN       NaN        NaN        NaN                      NaN
# 264        MANHATTAN   10011.0  40.738552 -73.999690   (40.738552, -73.99969)
# 348    STATEN ISLAND   10305.0  40.601006 -74.076454  (40.601006, -74.076454)
# 396              NaN       NaN  40.845024 -73.926320   (40.845024, -73.92632)
# ...              ...       ...        ...        ...                      ...
# 99981         QUEENS   11367.0  40.717674 -73.817130   (40.717674, -73.81713)
# 99982            NaN       NaN        NaN        NaN                      NaN
# 99985            NaN       NaN  40.838127 -73.919310   (40.838127, -73.91931)
# 99990       BROOKLYN   11218.0        NaN        NaN                      NaN
# 99992          BRONX   10461.0  40.836597 -73.840546  (40.836597, -73.840546)
#
# ...

# %%
trial_df.shape
# Out:
# (100000, 16)

# %%
trial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   borough                        64974 non-null   object
#  1   zip_code                       64966 non-null   float64
#  2   latitude                       91965 non-null   float64
#  3   longitude                      91965 non-null   float64
#  4   location                       91965 non-null   object
#  5   on_street_name                 73991 non-null   object
#  6   off_street_name                47125 non-null   object
#  7   cross_street_name              25967 non-null   object
#  8   number_of_persons_injured      100000 non-null  int64
#  9   number_of_persons_killed       100000 non-null  int64
#  10  number_of_pedestrians_injured  100000 non-null  int64
#  11  number_of_pedestrians_killed   100000 non-null  int64
# ...

# %%
trial_df.head()
# Out:
#          borough  zip_code   latitude  longitude                 location  \
# 0  STATEN ISLAND   10312.0  40.536728 -74.193344  (40.536728, -74.193344)
# 1          BRONX   10472.0  40.829052 -73.850380   (40.829052, -73.85038)
# 2         QUEENS   11420.0  40.677303 -73.804565  (40.677303, -73.804565)
# 3            NaN       NaN  40.624958 -74.145775  (40.624958, -74.145775)
# 4          BRONX   10456.0  40.828846 -73.903120   (40.828846, -73.90312)
#
#                      on_street_name   off_street_name  \
# 0                               NaN               NaN
# 1  CASTLE HILL AVENUE                BLACKROCK AVENUE
# 2  135 STREET                          FOCH BOULEVARD
# 3  FOREST AVENUE                      RICHMOND AVENUE
# 4                               NaN               NaN
#
#                           cross_street_name  number_of_persons_injured  \
# 0  243       DARLINGTON AVENUE                                       0
# ...

# %%
trial_df = relevant_df

# %%
relevant_df['collision_id'] = df['collision_id']

# %%
relevant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   borough                        64974 non-null   object
#  1   zip_code                       64966 non-null   float64
#  2   latitude                       91965 non-null   float64
#  3   longitude                      91965 non-null   float64
#  4   location                       91965 non-null   object
#  5   on_street_name                 73991 non-null   object
#  6   off_street_name                47125 non-null   object
#  7   cross_street_name              25967 non-null   object
#  8   number_of_persons_injured      100000 non-null  int64
#  9   number_of_persons_killed       100000 non-null  int64
#  10  number_of_pedestrians_injured  100000 non-null  int64
#  11  number_of_pedestrians_killed   100000 non-null  int64
# ...

# %%
relevant_df.duplicated().any()
# Out:
# False

# %%
relevant_df.isnull().sum()
# Out:
# borough                          35026
# zip_code                         35034
# latitude                          8035
# longitude                         8035
# location                          8035
# on_street_name                   26009
# off_street_name                  52875
# cross_street_name                74033
# number_of_persons_injured            0
# number_of_persons_killed             0
# number_of_pedestrians_injured        0
# number_of_pedestrians_killed         0
# number_of_cyclist_injured            0
# number_of_cyclist_killed             0
# number_of_motorist_injured           0
# number_of_motorist_killed            0
# collision_id                         0
# dtype: int64

# %%
relevant_df.describe()
# Out:
#            zip_code      latitude     longitude  number_of_persons_injured  \
# count  64966.000000  91965.000000  91965.000000              100000.000000
# mean   10901.653188     40.651917    -73.781995                   0.371960
# std      523.494905      1.746143      3.276307                   0.743916
# min    10000.000000      0.000000   -201.237060                   0.000000
# 25%    10457.000000     40.667915    -73.960870                   0.000000
# 50%    11209.000000     40.717724    -73.918110                   0.000000
# 75%    11354.000000     40.785595    -73.862860                   1.000000
# max    11697.000000     40.912170      0.000000                  15.000000
#
#        number_of_persons_killed  number_of_pedestrians_injured  \
# count             100000.000000                  100000.000000
# mean                   0.001930                       0.047390
# std                    0.046112                       0.223438
# ...

# %%
relevant_df['number_of_persons_injured'].max()
# Out:
# 15

# %%
a = pd.Index(relevant_df['number_of_persons_injured'])

# %%
a.get_loc(15)
# Out:
# 51661

# %%
relevant_df.loc[51661]
# Out:
# borough                                                  BROOKLYN
# zip_code                                                    11236
# latitude                                                  40.6323
# longitude                                                -73.9009
# location                                    (40.63226, -73.90088)
# on_street_name                   EAST 87 STREET
# off_street_name                                          AVENUE M
# cross_street_name                                             NaN
# number_of_persons_injured                                      15
# number_of_persons_killed                                        0
# number_of_pedestrians_injured                                   0
# number_of_pedestrians_killed                                    0
# number_of_cyclist_injured                                       0
# number_of_cyclist_killed                                        0
# ...

# %%
relevant_df.loc[51661].location
# Out:
# '(40.63226, -73.90088)'

# %%
relevant_df['number_of_persons_injured'].describe()
# Out:
# count    100000.000000
# mean          0.371960
# std           0.743916
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max          15.000000
# Name: number_of_persons_injured, dtype: float64

# %%
relevant_df.plot(y='number_of_persons_injured', x='borough')
plt.show()

# %%
df_by_borough = relevant_df.groupby(relevant_df['borough'], dropna=False).sum()

# %%
df_by_borough['number_of_persons_killed']
# Out:
# borough
# BRONX            15
# BROOKLYN         37
# MANHATTAN        17
# QUEENS           30
# STATEN ISLAND     5
# NaN              89
# Name: number_of_persons_killed, dtype: int64

# %%
df_by_borough['number_of_persons_injured']
# Out:
# borough
# BRONX             4209
# BROOKLYN          8137
# MANHATTAN         3053
# QUEENS            6086
# STATEN ISLAND      804
# NaN              14907
# Name: number_of_persons_injured, dtype: int64

# %%
df_by_location = relevant_df.groupby(relevant_df['location'], dropna=False).sum()

# %%
df_by_location
# Out:
#                           zip_code   latitude  longitude  \
# location
# (0.0, 0.0)               1426065.0   0.000000   0.000000
# (40.501465, -74.24523)     10307.0  40.501465 -74.245230
# (40.50331, -74.237465)         0.0  40.503310 -74.237465
# (40.503387, -74.24883)         0.0  40.503387 -74.248830
# (40.503414, -74.24496)     10307.0  40.503414 -74.244960
# ...                            ...        ...        ...
# (40.91038, -73.89663)      10471.0  40.910380 -73.896630
# (40.912018, -73.9)             0.0  40.912018 -73.900000
# (40.912117, -73.90268)     10471.0  40.912117 -73.902680
# (40.91217, -73.90077)      10471.0  40.912170 -73.900770
# NaN                     19798126.0   0.000000   0.000000
#
#                         number_of_persons_injured  number_of_persons_killed  \
# location
# (0.0, 0.0)                                     58                         1
# (40.501465, -74.24523)                          0                         0
# ...

# %%
df['number_of_persons_killed'].sum()
# Out:
# 193

# %%
df['number_of_persons_injured'].sum()
# Out:
# 37196

# %%
df_by_on_street = relevant_df.groupby(relevant_df['on_street_name']).sum()

# %%
df_by_on_street
# Out:
#                                    zip_code      latitude     longitude  \
# on_street_name
# 1 AVENUE                          1792874.0  11535.499583 -20930.720805
# 1 PLACE                             78617.0    284.762894   -517.980730
# 1 STREET                            45290.0    162.623393   -295.449620
# 1 avenue                                0.0      0.000000      0.000000
# 10 AVENUE                         1347980.0   7133.584019 -12946.663105
# ...                                     ...           ...           ...
# west 74 st                          10023.0      0.000000      0.000000
# west end ave                            0.0      0.000000      0.000000
# west street                         30026.0      0.000000      0.000000
# westchester ave                         0.0      0.000000      0.000000
# willis ave bridge                   10454.0      0.000000      0.000000
#
#                                   number_of_persons_injured  \
# on_street_name
# ...

# %%
df_by_on_street['number_of_persons_injured'].idxmax()
# Out:
# 'BELT PARKWAY                    '

# %%
df_by_on_street['number_of_persons_killed'].idxmax()
# Out:
# 'HENRY HUDSON PARKWAY            '

# %%
df_with_any_address = relevant_df.dropna(subset=['location', 'on_street_name', 'off_street_name', 'cross_street_name'], how='all')

# %%
df_with_any_address
# Out:
#              borough  zip_code   latitude  longitude                 location  \
# 0      STATEN ISLAND   10312.0  40.536728 -74.193344  (40.536728, -74.193344)
# 1              BRONX   10472.0  40.829052 -73.850380   (40.829052, -73.85038)
# 2             QUEENS   11420.0  40.677303 -73.804565  (40.677303, -73.804565)
# 3                NaN       NaN  40.624958 -74.145775  (40.624958, -74.145775)
# 4              BRONX   10456.0  40.828846 -73.903120   (40.828846, -73.90312)
# ...              ...       ...        ...        ...                      ...
# 99995       BROOKLYN   11210.0  40.618893 -73.946420   (40.618893, -73.94642)
# 99996         QUEENS   11367.0  40.723380 -73.814750    (40.72338, -73.81475)
# 99997       BROOKLYN   11249.0  40.710820 -73.968530    (40.71082, -73.96853)
# 99998       BROOKLYN   11234.0  40.631180 -73.928185   (40.63118, -73.928185)
# 99999      MANHATTAN   10017.0  40.750760 -73.968430    (40.75076, -73.96843)
#
# ...

# %%
df_with_location = relevant_df.dropna(subset=['location'])

# %%
df_with_location
# Out:
#              borough  zip_code   latitude  longitude                 location  \
# 0      STATEN ISLAND   10312.0  40.536728 -74.193344  (40.536728, -74.193344)
# 1              BRONX   10472.0  40.829052 -73.850380   (40.829052, -73.85038)
# 2             QUEENS   11420.0  40.677303 -73.804565  (40.677303, -73.804565)
# 3                NaN       NaN  40.624958 -74.145775  (40.624958, -74.145775)
# 4              BRONX   10456.0  40.828846 -73.903120   (40.828846, -73.90312)
# ...              ...       ...        ...        ...                      ...
# 99995       BROOKLYN   11210.0  40.618893 -73.946420   (40.618893, -73.94642)
# 99996         QUEENS   11367.0  40.723380 -73.814750    (40.72338, -73.81475)
# 99997       BROOKLYN   11249.0  40.710820 -73.968530    (40.71082, -73.96853)
# 99998       BROOKLYN   11234.0  40.631180 -73.928185   (40.63118, -73.928185)
# 99999      MANHATTAN   10017.0  40.750760 -73.968430    (40.75076, -73.96843)
#
# ...

# %% [markdown]
# ## Try to fill in NaN values

# %%
df.head()
# Out:
#                 crash_date crash_time        borough  zip_code   latitude  \
# 0  2017-04-18T00:00:00.000      23:10  STATEN ISLAND   10312.0  40.536728
# 1  2017-05-06T00:00:00.000      13:00          BRONX   10472.0  40.829052
# 2  2017-04-27T00:00:00.000      17:15         QUEENS   11420.0  40.677303
# 3  2017-05-09T00:00:00.000      20:10            NaN       NaN  40.624958
# 4  2017-04-18T00:00:00.000      14:00          BRONX   10456.0  40.828846
#
#    longitude                 location                    on_street_name  \
# 0 -74.193344  (40.536728, -74.193344)                               NaN
# 1 -73.850380   (40.829052, -73.85038)  CASTLE HILL AVENUE
# 2 -73.804565  (40.677303, -73.804565)  135 STREET
# 3 -74.145775  (40.624958, -74.145775)  FOREST AVENUE
# 4 -73.903120   (40.828846, -73.90312)                               NaN
#
#     off_street_name                         cross_street_name  ...  \
# 0               NaN  243       DARLINGTON AVENUE               ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_date                     100000 non-null  object
#  1   crash_time                     100000 non-null  object
#  2   borough                        64974 non-null   object
#  3   zip_code                       64966 non-null   float64
#  4   latitude                       91965 non-null   float64
#  5   longitude                      91965 non-null   float64
#  6   location                       91965 non-null   object
#  7   on_street_name                 73991 non-null   object
#  8   off_street_name                47125 non-null   object
#  9   cross_street_name              25967 non-null   object
#  10  number_of_persons_injured      100000 non-null  int64
#  11  number_of_persons_killed       100000 non-null  int64
# ...

# %%
df_nan_gone = df.dropna(subset=['location', 'on_street_name', 'off_street_name', 'cross_street_name'], how='all')

# %%
df_nan_gone
# Out:
#                     crash_date crash_time        borough  zip_code   latitude  \
# 0      2017-04-18T00:00:00.000      23:10  STATEN ISLAND   10312.0  40.536728
# 1      2017-05-06T00:00:00.000      13:00          BRONX   10472.0  40.829052
# 2      2017-04-27T00:00:00.000      17:15         QUEENS   11420.0  40.677303
# 3      2017-05-09T00:00:00.000      20:10            NaN       NaN  40.624958
# 4      2017-04-18T00:00:00.000      14:00          BRONX   10456.0  40.828846
# ...                        ...        ...            ...       ...        ...
# 99995  2019-11-20T00:00:00.000      15:00       BROOKLYN   11210.0  40.618893
# 99996  2019-12-01T00:00:00.000      11:22         QUEENS   11367.0  40.723380
# 99997  2019-11-21T00:00:00.000      21:30       BROOKLYN   11249.0  40.710820
# 99998  2019-11-18T00:00:00.000      17:28       BROOKLYN   11234.0  40.631180
# 99999  2019-11-17T00:00:00.000      20:42      MANHATTAN   10017.0  40.750760
#
# ...

# %%
df_nan_gone['zip_code'] = df_nan_gone['zip_code'].astype(pd.Int32Dtype())
# Out:
# <ipython-input-25-5140133e5380>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nan_gone['zip_code'] = df_nan_gone['zip_code'].astype(pd.Int32Dtype())

# %%
df_nan_gone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99987 entries, 0 to 99999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   crash_date                     99987 non-null  object
#  1   crash_time                     99987 non-null  object
#  2   borough                        64974 non-null  object
#  3   zip_code                       64966 non-null  Int32
#  4   latitude                       91965 non-null  float64
#  5   longitude                      91965 non-null  float64
#  6   location                       91965 non-null  object
#  7   on_street_name                 73991 non-null  object
#  8   off_street_name                47125 non-null  object
#  9   cross_street_name              25967 non-null  object
#  10  number_of_persons_injured      99987 non-null  int64
#  11  number_of_persons_killed       99987 non-null  int64
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-c9d10be4e81f> in <module>
# ----> 1 int(df_nan_gone['location'][0][1:-1])
#
# ValueError: invalid literal for int() with base 10: '40.536728, -74.193344'
